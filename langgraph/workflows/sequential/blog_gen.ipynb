# %%
import os
from dotenv import load_dotenv
from typing import TypedDict

load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
from langchain_deepseek import ChatDeepSeek
from langgraph.graph import StateGraph, START, END
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.output_parsers import StrOutputParser

# %%
LLMS = {}

LLMS['gemini'] = ChatGoogleGenerativeAI(
    api_key = os.getenv("GOOGLE_API_KEY"),
    model = 'gemini-1.5-flash'
)

LLMS['deepseek'] = ChatDeepSeek(
    api_key=os.getenv("OPENROUTER_API_KEY"),
    api_base=os.getenv("OPENROUTER_BASE_URL"),
    model="deepseek/deepseek-chat-v3-0324:free"
)

LLMS['moonshotai'] = ChatGroq(
    api_key = os.getenv("GROQ_API_KEY"),
    model = "moonshotai/kimi-k2-instruct"
)

# %%
llm = LLMS['deepseek']

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content: str

# %%
outline_prompt = ChatPromptTemplate.from_messages([
    ("system", """
    You are an expert blog strategist.
    Given a blog topic, your job is to create a clear, engaging outline that a smart human writer could confidently use to write a great article.

    Keep these in mind:

    - Start with a working title (can be improved later).
    - Break the blog down into sections with informative headings.
    - Under each heading, add brief bullet points on what should be covered.
    - Structure should have a clear intro, a logical flow of main sections, and a strong wrap-up or conclusion.
    - Use natural language. No corporate buzzwords, no generic filler like “content is king.”
    - Don't force trends or clichés unless they genuinely fit.
    - Aim for clarity, usefulness, and a bit of personality.
    - Optionally, suggest a few subtopics, angles, or FAQs if helpful.

    Your tone should feel like a thoughtful, experienced content editor helping a writer get started.
    Make it feel intentional, not autogenerated.
    """),
    ("human", "Generate an outline for this title: {title}")
])

# %%
blog_prompt = ChatPromptTemplate.from_messages([
    ("system", """
    You are a skilled, thoughtful blog writer.
    You're given a topic and an outline—your job is to turn them into a complete, engaging blog post that reads like it was written by a smart, confident human.

    Follow these principles:

    - Stick to the outline, but feel free to improve flow or connect sections smoothly.
    - Write with a clear, natural voice. Imagine explaining the topic to a smart peer—not oversimplified, not overly formal.
    - Avoid robotic phrases, buzzwords, and filler like:
        “In today's digital age”
        “Leveraging synergies”
        “Cutting-edge solutions”
    - No padding. No corporate fluff. Every paragraph should have purpose.
    - Use conversational transitions where it helps (e.g., “Here's the thing,” “Let's break it down,” “What this really means is…”).
    - Vary sentence structure and rhythm like a real human would.
    - If helpful, use light humor, metaphors, or relatable examples—but don't overdo it.
    - Where appropriate, use emojis sparingly to make it feel friendly 😊
    - End with a clear, satisfying conclusion—either a takeaway, call to action, or reflection.

    Tone: Clear, confident, real. Not trying to impress. Just trying to be helpful and readable.
    """),
    ("human", """
        Generate the blog for the below given topic:
        {title}.
        Here is the outline for this:
        {outline}
    """)
])

# %%
def create_outline(state: BlogState) -> BlogState:
    title = state['title']
    outline_chain = outline_prompt | llm | StrOutputParser()
    outline = outline_chain.invoke(input={
        'title': title,
    })
    state['outline'] = outline
    
    return state

# %%
def create_blog(state: BlogState) -> BlogState:
    title = state['title']
    outline = state['outline']
    blog_chain = blog_prompt | llm | StrOutputParser()
    content = blog_chain.invoke(input={
        'title': title,
        'outline': outline
    })
    state['content'] = content
    
    return state

# %%
graph = StateGraph(BlogState)

graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
initial_state = {
    'title': "How to build habits that don't fall apart after 3 days"
}

final_state = workflow.invoke(initial_state)
# print(final_state)

# %%
print(final_state['title'])
print("*"*100)
print(final_state['outline'])
print("*"*100)
print(final_state['content'])
# Out:
# How to build habits that don't fall apart after 3 days
# ****************************************************************************************************
# **Title:** *How to Build Habits That Don’t Fall Apart After 3 Days*
#
# **Intro:**
# - Open with a relatable anecdote or stat about how most people fail at new habits within days—but why that’s not the whole story.
# - Emphasize that the problem isn’t willpower; it’s strategy.
# - Preview the actionable steps ahead.
#
# ### **1. Start Smaller Than You Think**
# - Why tiny habits work: The brain resists big changes, not small ones.
# - Example: "Floss one tooth" vs. "Floss all your teeth."
# - How to scale down any goal to something laughably easy—and why that builds momentum.
#
# ### **2. Attach New Habits to Existing Ones (Habit Stacking)**
# - The science of cue-routine-reward loops.
# - Formula: "After [current habit], I’ll do [new habit]."
# - Example: "After I pour my morning coffee, I’ll write one sentence in my journal."
# - Common mistakes (e.g., pairing habits that don’t logically fit).
#
# ### **3. Design for Consistency, Not Perfection**
# - Why "never miss twice" is more realistic than "never miss."
# - The 2-day rule: How to recover without guilt after a slip-up.
# - Case study: How fitness trackers or apps exploit this principle (streaks).
#
# ### **4. Make It Obvious (Or Invisible, for Bad Habits)**
# - Cues matter: Leave your yoga mat by the bed; hide the junk food.
# - The role of environment: How your space shapes your behavior more than motivation.
# - Example: Want to read more? Leave a book on your pillow every morning.
#
# ### **5. Celebrate Tiny Wins**
# - Why dopamine reinforces habits—and how to hack it.
# - Examples: A checkmark on a calendar, a mental "Nice!" after doing the thing.
# - Warning: Don’t skip this step because it feels silly.
#
# ### **6. Know When to Level Up**
# - Signs your habit is too easy now—and how to carefully increase the challenge.
# - The "Goldilocks Zone": Not so hard you quit, not so easy you’re bored.
#
# **Closing:**
# - Recap the big idea: Habits stick when they’re small, linked, and rewarding.
# - Final tip: Track progress but focus on systems, not streaks.
# - Encouragement: "You’re not failing; you’re refining."
#
# **Optional FAQ Angle:**
# - *"What if I keep forgetting?"* → Tie habits to visual/auditory cues.
# - *"How long until it’s automatic?"* → It varies; focus on repetition, not time.
#
# **Tone Note:** Keep it encouraging but no-nonsense—like a coach who believes in tough love *and* high-fives.
#
# ---
# **Why This Works:**
# - Skips vague advice ("just be disciplined!") for tactical steps.
# - Balances science with relatable examples.
# - Addresses common pain points (guilt, forgetfulness) head-on.
#
# **Bonus Ideas for Later:**
# - A sidebar on "habit myths" (e.g., "21 days to form a habit").
# - Interview a psychologist or habit researcher for quotes.
# ****************************************************************************************************
# # **How to Build Habits That Don’t Fall Apart After 3 Days**
#
# We’ve all been there: Day 1, full of motivation. Day 2, still going strong. Day 3… oops, missed it. By Day 7? Forgotten entirely.
#
# Here’s the good news: The problem isn’t *you*—it’s your strategy. Willpower is unreliable. A smart system, though? That sticks.
#
# Let’s fix that.
#
# ---
#
# ### **1. Start Smaller Than You Think**
# Your brain hates abrupt change. It triggers resistance—like trying to sprint without warming up.
#
# Instead of *"Work out for 30 minutes,"* try *"Put on workout clothes."* Instead of *"Floss all teeth,"* start with *"Floss one tooth."*
#
# Why it works:
# - Tiny actions feel doable, so you actually do them.
# - Success builds momentum. (Flossing one tooth often leads to flossing them all.)
# - Over time, the habit grows naturally.
#
# **Try this:** Pick a goal. Now cut it in half. Then halve it again. That’s your starting point.
#
# ---
#
# ### **2. Attach New Habits to Existing Ones**
# Habits thrive on cues. Your brain loves patterns: *"After X, I do Y."*
#
# This is **habit stacking**:
#
# - *"After I brush my teeth, I’ll do two push-ups."*
# - *"After I pour my coffee, I’ll write one sentence in my journal."*
#
# **Avoid:** Pairing habits that don’t make sense (e.g., *"After I shower, I’ll study Spanish"*—no clear link).
#
# ---
#
# ### **3. Design for Consistency, Not Perfection**
# Miss a day? No guilt. Just follow the **two-day rule**: Never miss *twice* in a row.
#
# Fitness apps exploit this with streaks—because missing once feels less scary than breaking the chain.
#
# **Ask yourself:** *"Would I rather do 80% of the time or quit after two weeks?"*
#
# ---
#
# ### **4. Make It Obvious (Or Invisible, for Bad Habits)**
# Your environment shapes behavior more than motivation:
#
# - Want to read more? **Leave a book on your pillow.**
# - Want to snack less? **Hide the junk food (or don’t buy it).**
# - Want to stretch daily? **Put your yoga mat where you’ll trip over it.**
#
# Bonus: Remove friction. Pack your gym bag the night before. Pre-chop veggies.
#
# ---
#
# ### **5. Celebrate Tiny Wins**
# Dopamine—the brain’s "do that again" chemical—reinforces habits. But we often skip celebrations because they feel silly.
#
# Instead:
# - ✔️ Mark an X on a calendar.
# - 🤸‍♂️ Do a mini dance after your push-ups.
# - 🎉 Just think *"Hell yeah, I did it."*
#
# **This isn’t optional:** Celebration trains your brain to *want* the habit.
#
# ---
#
# ### **6. Know When to Level Up**
# If your habit feels *too* easy, nudge it:
#
# - Reading one page? Try two.
# - Two push-ups? Try five.
#
# The **Goldilocks Zone**: Challenging enough to stay interesting, but not so hard you quit.
#
# ---
#
# ## **The Big Takeaway**
# Habits stick when they’re:
# ✅ **Small** (no resistance)
# ✅ **Linked** (stacked onto existing routines)
# ✅ **Rewarding** (celebrate the micro-wins)
#
# **Final tip:** Track progress, but focus on the *system*, not streaks. You’re not failing—you’re refining.
#
# ---
#
# ### **FAQ Quick Hits**
# **"What if I keep forgetting?"**
# → Make the cue *obvious* (alarms, sticky notes)
#
# **"How long until it’s automatic?"**
# → Forget "21 days." Some take weeks, some months. Repetition > time.
#
# Now go floss one tooth. 😉
